# %% [markdown]
# ## League Of Legends Win Rate Classification Problem

# %% [markdown]
# ![Alt text](./map.jpeg)
#
# #### Understanding the Game
# - This is a multiplayer 5v5 game where both teams have the same goal of destroying the "nexus", which is just a building in the base. Each team has to defend their own nexus and attack the enemies at the same time. There are also many towers to get through before reaching the nexus. There are a 162 league champions to pick from each with their own advantages and disadvantages.
# - The game rewards you with gold for destroying towers and killing your enemies. With gold you can buy items to make your champion stronger by providing bonus stats.
# - Champions can level up during the game by killing enemies which will allow them to unlock abilities and make them stronger. A level is nearly equivalent to 500 gold in stats.
# ```
#     Gold -> Items -> Kills
#     Experience -> Levels -> Kills
#     Kills -> Gold
# ```
#
# - The area of the map in which a team does not have sight over is known as the Fog of War, a common hallmark of the RTS genre which is represented visually as a dark shroud over the terrain. Vision is the power to light up certain areas you choose in order to see everything that comes in contact with it. This can be created and controlled using items such as wards, trinkets and control wards. Using these items to attain vision will help yourself and your team to not get ambush by the enemy team, thus leading to less overall deaths.
#
# ```
#     Wards -> Vision -> Avoiding Ganks (Dying less)
# ```
#
# - The main goal of the game is to destroy the enemies nexus (base core), and in order to do that then Ally team must push at least 1 lane all the way through to the base. This requires destroying towers and inhibators. Although before 10 minutes, the game is setup so it's harder to push for towers as they have alot of Health and your champion does little damage. If a team is able to get a tower before this time it's a strong indicator that they are in the lead.
#
# ```
#     Destroy Tower -> Destroy Inhibators -> Destroy Nexus -> Win Game
# ```
#
# - Before 10 minutes there are also 2 different elite monsters, red brambleback and blue sentinel which provides the killer a temporary buff, a team could also take the dragon which provides extra stats and the rift herald which provides a team with gold stipend.

# %% [markdown]
# ## 1) The Data Set
#
# The goal for this dataset is to predict wether team blue would win in the first 10 minutes of a league of legends game.
#
# This dataset aims to predict the class attribute blueWins, and uses all other feature to predict this value. This is a binary classification, meaning blue team would either win or lose.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# Libraries to help with visualisation
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Show all attributes
pd.set_option('display.max_columns', None)
pd.set_option('mode.chained_assignment', None)
# %matplotlib inline
sns.set_style('darkgrid')

print('Libraries Imported!')
# Out:
# Libraries Imported!

# %% [markdown]
# ## 2) Raw Data Analysis

# %%
# Read into dataframe
df = pd.read_csv('inputs/high_diamond_ranked_10min.csv')
df.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0          9           6           11                  0            0
# 1          5           5            5                  0            0
# 2          7          11            4                  1            1
# 3          4           5            5                  1            0
# 4          6           6            6                  0            0
#
#    blueHeralds  blueTowersDestroyed  blueTotalGold  blueAvgLevel  \
# 0            0                    0          17210           6.6
# 1            0                    0          14712           6.6
# 2            0                    0          16113           6.4
# 3            1                    0          15157           7.0
# 4            0                    0          16400           7.0
#
#    blueTotalExperience  blueTotalMinionsKilled  blueTotalJungleMinionsKilled  \
# 0                17039                     195                            36
# 1                16265                     174                            43
# 2                16221                     186                            46
# 3                17954                     201                            55
# 4                18543                     210                            57
#
#    blueGoldDiff  blueExperienceDiff  blueCSPerMin  blueGoldPerMin  \
# 0           643                  -8          19.5          1721.0
# 1         -2908               -1173          17.4          1471.2
# 2         -1172               -1033          18.6          1611.3
# 3         -1321                  -7          20.1          1515.7
# 4         -1004                 230          21.0          1640.0
#
#    redWardsPlaced  redWardsDestroyed  redFirstBlood  redKills  redDeaths  \
# 0              15                  6              0         6          9
# 1              12                  1              1         5          5
# 2              15                  3              1        11          7
# 3              15                  2              1         5          4
# 4              17                  2              1         6          6
#
#    redAssists  redEliteMonsters  redDragons  redHeralds  redTowersDestroyed  \
# 0           8                 0           0           0                   0
# 1           2                 2           1           1                   1
# 2          14                 0           0           0                   0
# 3          10                 0           0           0                   0
# 4           7                 1           1           0                   0
#
#    redTotalGold  redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# 0         16567          6.8               17047                    197
# 1         17620          6.8               17438                    240
# 2         17285          6.8               17254                    203
# 3         16478          7.0               17961                    235
# 4         17404          7.0               18313                    225
#
#    redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  redCSPerMin  \
# 0                           55         -643                  8         19.7
# 1                           52         2908               1173         24.0
# 2                           28         1172               1033         20.3
# 3                           47         1321                  7         23.5
# 4                           67         1004               -230         22.5
#
#    redGoldPerMin
# 0         1656.7
# 1         1762.0
# 2         1728.5
# 3         1647.8
# 4         1740.4

# %%
df.shape
# Out:
# (9879, 40)

# %% [markdown]
# Df has 9879 rows and 40 columns(attributes). Knowing this we can review it later on and examine which attributes will be necessary and the type of data manipulation that will be needed before creating our prediction model.

# %%
# Check for null values 
df.isnull().sum()
# Out:
# gameId                          0
# blueWins                        0
# blueWardsPlaced                 0
# blueWardsDestroyed              0
# blueFirstBlood                  0
# blueKills                       0
# blueDeaths                      0
# blueAssists                     0
# blueEliteMonsters               0
# blueDragons                     0
# blueHeralds                     0
# blueTowersDestroyed             0
# blueTotalGold                   0
# blueAvgLevel                    0
# blueTotalExperience             0
# blueTotalMinionsKilled          0
# blueTotalJungleMinionsKilled    0
# blueGoldDiff                    0
# blueExperienceDiff              0
# blueCSPerMin                    0
# blueGoldPerMin                  0
# redWardsPlaced                  0
# redWardsDestroyed               0
# redFirstBlood                   0
# redKills                        0
# redDeaths                       0
# redAssists                      0
# redEliteMonsters                0
# redDragons                      0
# redHeralds                      0
# redTowersDestroyed              0
# redTotalGold                    0
# redAvgLevel                     0
# redTotalExperience              0
# redTotalMinionsKilled           0
# redTotalJungleMinionsKilled     0
# redGoldDiff                     0
# redExperienceDiff               0
# redCSPerMin                     0
# redGoldPerMin                   0
# dtype: int64

# %% [markdown]
# ## 3) Feature Engineering
#
# ##### Class Variable is "blueWins"
#
# The first two features we can modify is the gameID, this provides our model with no significant or useful information to make a decision on the likelyhood of blue side winning the game.
#
# We will also move our blueWins attribute out of the column and place it into a variable "target".

# %%
# store target variable in target
target = df.blueWins

# drop target and gameId
df.drop(['blueWins', 'gameId'], axis=1, inplace=True)
df.head()
# Out:
#    blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  blueDeaths  \
# 0               28                   2               1          9           6
# 1               12                   1               0          5           5
# 2               15                   0               0          7          11
# 3               43                   1               0          4           5
# 4               75                   4               0          6           6
#
#    blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# 0           11                  0            0            0
# 1            5                  0            0            0
# 2            4                  1            1            0
# 3            5                  1            0            1
# 4            6                  0            0            0
#
#    blueTowersDestroyed  blueTotalGold  blueAvgLevel  blueTotalExperience  \
# 0                    0          17210           6.6                17039
# 1                    0          14712           6.6                16265
# 2                    0          16113           6.4                16221
# 3                    0          15157           7.0                17954
# 4                    0          16400           7.0                18543
#
#    blueTotalMinionsKilled  blueTotalJungleMinionsKilled  blueGoldDiff  \
# 0                     195                            36           643
# 1                     174                            43         -2908
# 2                     186                            46         -1172
# 3                     201                            55         -1321
# 4                     210                            57         -1004
#
#    blueExperienceDiff  blueCSPerMin  blueGoldPerMin  redWardsPlaced  \
# 0                  -8          19.5          1721.0              15
# 1               -1173          17.4          1471.2              12
# 2               -1033          18.6          1611.3              15
# 3                  -7          20.1          1515.7              15
# 4                 230          21.0          1640.0              17
#
#    redWardsDestroyed  redFirstBlood  redKills  redDeaths  redAssists  \
# 0                  6              0         6          9           8
# 1                  1              1         5          5           2
# 2                  3              1        11          7          14
# 3                  2              1         5          4          10
# 4                  2              1         6          6           7
#
#    redEliteMonsters  redDragons  redHeralds  redTowersDestroyed  redTotalGold  \
# 0                 0           0           0                   0         16567
# 1                 2           1           1                   1         17620
# 2                 0           0           0                   0         17285
# 3                 0           0           0                   0         16478
# 4                 1           1           0                   0         17404
#
#    redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# 0          6.8               17047                    197
# 1          6.8               17438                    240
# 2          6.8               17254                    203
# 3          7.0               17961                    235
# 4          7.0               18313                    225
#
#    redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  redCSPerMin  \
# 0                           55         -643                  8         19.7
# 1                           52         2908               1173         24.0
# 2                           28         1172               1033         20.3
# 3                           47         1321                  7         23.5
# 4                           67         1004               -230         22.5
#
#    redGoldPerMin
# 0         1656.7
# 1         1762.0
# 2         1728.5
# 3         1647.8
# 4         1740.4

# %% [markdown]
# After Checking the bias balance on the dataset, it is well even at 50/50

# %%
# check the balance of the data set
# visualize blueWins using countplot
sns.countplot(target, label='Count', palette='RdBu')
W, L = target.value_counts()

print('Red Wins: {} ({}%), Blue Wins: {}({}%)'.format(W,round(100*W/(W+L),3),L,round(100*L/(W+L),3)))
# Out:
# Red Wins: 4949 (50.096%), Blue Wins: 4930(49.904%)

# %%
df.describe()
# Out:
#        blueWardsPlaced  blueWardsDestroyed  blueFirstBlood    blueKills  \
# count      9879.000000         9879.000000     9879.000000  9879.000000
# mean         22.288288            2.824881        0.504808     6.183925
# std          18.019177            2.174998        0.500002     3.011028
# min           5.000000            0.000000        0.000000     0.000000
# 25%          14.000000            1.000000        0.000000     4.000000
# 50%          16.000000            3.000000        1.000000     6.000000
# 75%          20.000000            4.000000        1.000000     8.000000
# max         250.000000           27.000000        1.000000    22.000000
#
#         blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# count  9879.000000  9879.000000        9879.000000  9879.000000  9879.000000
# mean      6.137666     6.645106           0.549954     0.361980     0.187974
# std       2.933818     4.064520           0.625527     0.480597     0.390712
# min       0.000000     0.000000           0.000000     0.000000     0.000000
# 25%       4.000000     4.000000           0.000000     0.000000     0.000000
# 50%       6.000000     6.000000           0.000000     0.000000     0.000000
# 75%       8.000000     9.000000           1.000000     1.000000     0.000000
# max      22.000000    29.000000           2.000000     1.000000     1.000000
#
#        blueTowersDestroyed  blueTotalGold  blueAvgLevel  blueTotalExperience  \
# count          9879.000000    9879.000000   9879.000000          9879.000000
# mean              0.051422   16503.455512      6.916004         17928.110133
# std               0.244369    1535.446636      0.305146          1200.523764
# min               0.000000   10730.000000      4.600000         10098.000000
# 25%               0.000000   15415.500000      6.800000         17168.000000
# 50%               0.000000   16398.000000      7.000000         17951.000000
# 75%               0.000000   17459.000000      7.200000         18724.000000
# max               4.000000   23701.000000      8.000000         22224.000000
#
#        blueTotalMinionsKilled  blueTotalJungleMinionsKilled  blueGoldDiff  \
# count             9879.000000                   9879.000000   9879.000000
# mean               216.699565                     50.509667     14.414111
# std                 21.858437                      9.898282   2453.349179
# min                 90.000000                      0.000000 -10830.000000
# 25%                202.000000                     44.000000  -1585.500000
# 50%                218.000000                     50.000000     14.000000
# 75%                232.000000                     56.000000   1596.000000
# max                283.000000                     92.000000  11467.000000
#
#        blueExperienceDiff  blueCSPerMin  blueGoldPerMin  redWardsPlaced  \
# count         9879.000000   9879.000000     9879.000000     9879.000000
# mean           -33.620306     21.669956     1650.345551       22.367952
# std           1920.370438      2.185844      153.544664       18.457427
# min          -9333.000000      9.000000     1073.000000        6.000000
# 25%          -1290.500000     20.200000     1541.550000       14.000000
# 50%            -28.000000     21.800000     1639.800000       16.000000
# 75%           1212.000000     23.200000     1745.900000       20.000000
# max           8348.000000     28.300000     2370.100000      276.000000
#
#        redWardsDestroyed  redFirstBlood     redKills    redDeaths  \
# count        9879.000000    9879.000000  9879.000000  9879.000000
# mean            2.723150       0.495192     6.137666     6.183925
# std             2.138356       0.500002     2.933818     3.011028
# min             0.000000       0.000000     0.000000     0.000000
# 25%             1.000000       0.000000     4.000000     4.000000
# 50%             2.000000       0.000000     6.000000     6.000000
# 75%             4.000000       1.000000     8.000000     8.000000
# max            24.000000       1.000000    22.000000    22.000000
#
#         redAssists  redEliteMonsters   redDragons   redHeralds  \
# count  9879.000000       9879.000000  9879.000000  9879.000000
# mean      6.662112          0.573135     0.413098     0.160036
# std       4.060612          0.626482     0.492415     0.366658
# min       0.000000          0.000000     0.000000     0.000000
# 25%       4.000000          0.000000     0.000000     0.000000
# 50%       6.000000          0.000000     0.000000     0.000000
# 75%       9.000000          1.000000     1.000000     0.000000
# max      28.000000          2.000000     1.000000     1.000000
#
#        redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# count         9879.000000   9879.000000  9879.000000         9879.000000
# mean             0.043021  16489.041401     6.925316        17961.730438
# std              0.216900   1490.888406     0.305311         1198.583912
# min              0.000000  11212.000000     4.800000        10465.000000
# 25%              0.000000  15427.500000     6.800000        17209.500000
# 50%              0.000000  16378.000000     7.000000        17974.000000
# 75%              0.000000  17418.500000     7.200000        18764.500000
# max              2.000000  22732.000000     8.200000        22269.000000
#
#        redTotalMinionsKilled  redTotalJungleMinionsKilled   redGoldDiff  \
# count            9879.000000                  9879.000000   9879.000000
# mean              217.349226                    51.313088    -14.414111
# std                21.911668                    10.027885   2453.349179
# min               107.000000                     4.000000 -11467.000000
# 25%               203.000000                    44.000000  -1596.000000
# 50%               218.000000                    51.000000    -14.000000
# 75%               233.000000                    57.000000   1585.500000
# max               289.000000                    92.000000  10830.000000
#
#        redExperienceDiff  redCSPerMin  redGoldPerMin
# count        9879.000000  9879.000000    9879.000000
# mean           33.620306    21.734923    1648.904140
# std          1920.370438     2.191167     149.088841
# min         -8348.000000    10.700000    1121.200000
# 25%         -1212.000000    20.300000    1542.750000
# 50%            28.000000    21.800000    1637.800000
# 75%          1290.500000    23.300000    1741.850000
# max          9333.000000    28.900000    2273.200000

# %% [markdown]
# As we can see from the table above, we have many columns which reference the same attributes but for both blue and red side. For example we have blueGoldDiff and redGoldDiff but these are always the same (the other one is just negative). This applies to redKills, redDeaths, redExperienceDiff.
#
# There is also redFirstBlood and blueFirstBlood, if one of the teams gets the first blood (which gives more gold than a normal kill) it means the other team did not, this means that it's useless to have a column for both blue and red.
#
# Lastly, the attributes that evaluate gold and cs per minute are not very useful either as we have the total cs given and we know that all the stats are up at the 10 minute mark. This shouldnt make a difference as it doesnt provide any information that isnt already given. We can see this lack of new information in the description above if we compare redTotalMinionsKilled column and the redCSPerMin column.
#
# Below we will remove the attributes that we deemed not useful.

# %%
# drop not useful columns of blue and red team
columns =   ['blueGoldPerMin', 'blueCSPerMin','redGoldPerMin',
            'redKills', 'redDeaths','redGoldDiff',
            'redExperienceDiff', 'redFirstBlood','redCSPerMin',
            'redTotalGold','redTotalExperience', 'blueTotalGold',
            'blueTotalExperience']
df_clean = df.drop(columns, axis=1)

# Show new table
df_clean.head()
# Out:
#    blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  blueDeaths  \
# 0               28                   2               1          9           6
# 1               12                   1               0          5           5
# 2               15                   0               0          7          11
# 3               43                   1               0          4           5
# 4               75                   4               0          6           6
#
#    blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# 0           11                  0            0            0
# 1            5                  0            0            0
# 2            4                  1            1            0
# 3            5                  1            0            1
# 4            6                  0            0            0
#
#    blueTowersDestroyed  blueAvgLevel  blueTotalMinionsKilled  \
# 0                    0           6.6                     195
# 1                    0           6.6                     174
# 2                    0           6.4                     186
# 3                    0           7.0                     201
# 4                    0           7.0                     210
#
#    blueTotalJungleMinionsKilled  blueGoldDiff  blueExperienceDiff  \
# 0                            36           643                  -8
# 1                            43         -2908               -1173
# 2                            46         -1172               -1033
# 3                            55         -1321                  -7
# 4                            57         -1004                 230
#
#    redWardsPlaced  redWardsDestroyed  redAssists  redEliteMonsters  \
# 0              15                  6           8                 0
# 1              12                  1           2                 2
# 2              15                  3          14                 0
# 3              15                  2          10                 0
# 4              17                  2           7                 1
#
#    redDragons  redHeralds  redTowersDestroyed  redAvgLevel  \
# 0           0           0                   0          6.8
# 1           1           1                   1          6.8
# 2           0           0                   0          6.8
# 3           0           0                   0          7.0
# 4           1           0                   0          7.0
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled
# 0                    197                           55
# 1                    240                           52
# 2                    203                           28
# 3                    235                           47
# 4                    225                           67

# %% [markdown]
# ### 4) Attributes encoding
#
# The next three lines are used to standardise all of our data using the z score. We take our (value - mean)/ standard deviation. This provides us with a much smaller range of values to work with and we are able to start comparing different attributes to eachother. When before 9000 gold diff might matter more than 3 ward kill since the numbers were drastrically different.
#
# Please note, this section is placed under feature engineering as we use this standardised data to create many of our graphs below and use them to determine which attributes to keep and remove.

# %%
# Copy attribute matrix and standardize it to compare all features at a even scale
data = df_clean.copy()
data_std = (data - data.mean()) / data.std()
data_std.head()
# Out:
#    blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  blueDeaths  \
# 0         0.316980           -0.379256        0.990379   0.935254   -0.046924
# 1        -0.570963           -0.839026       -1.009612  -0.393196   -0.387777
# 2        -0.404474           -1.298797       -1.009612   0.271029    1.657340
# 3         1.149426           -0.839026       -1.009612  -0.725309   -0.387777
# 4         2.925312            0.540285       -1.009612  -0.061084   -0.046924
#
#    blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# 0     1.071441          -0.879186    -0.753188    -0.481108
# 1    -0.404748          -0.879186    -0.753188    -0.481108
# 2    -0.650779           0.719467     1.327556    -0.481108
# 3    -0.404748           0.719467    -0.753188     2.078325
# 4    -0.158716          -0.879186    -0.753188    -0.481108
#
#    blueTowersDestroyed  blueAvgLevel  blueTotalMinionsKilled  \
# 0            -0.210428     -1.035582               -0.992732
# 1            -0.210428     -1.035582               -1.953459
# 2            -0.210428     -1.691007               -1.404472
# 3            -0.210428      0.275266               -0.718238
# 4            -0.210428      0.275266               -0.306498
#
#    blueTotalJungleMinionsKilled  blueGoldDiff  blueExperienceDiff  \
# 0                     -1.465877      0.256215            0.013341
# 1                     -0.758684     -1.191194           -0.593312
# 2                     -0.455601     -0.483590           -0.520410
# 3                      0.453648     -0.544323            0.013862
# 4                      0.655703     -0.415112            0.137276
#
#    redWardsPlaced  redWardsDestroyed  redAssists  redEliteMonsters  \
# 0       -0.399186           1.532415    0.329479         -0.914847
# 1       -0.561723          -0.805829   -1.148130          2.277585
# 2       -0.399186           0.129469    1.807089         -0.914847
# 3       -0.399186          -0.338180    0.822016         -0.914847
# 4       -0.290829          -0.338180    0.083211          0.681369
#
#    redDragons  redHeralds  redTowersDestroyed  redAvgLevel  \
# 0   -0.838923   -0.436473           -0.198343    -0.410454
# 1    1.191884    2.290861            4.412078    -0.410454
# 2   -0.838923   -0.436473           -0.198343    -0.410454
# 3   -0.838923   -0.436473           -0.198343     0.244615
# 4    1.191884   -0.436473           -0.198343     0.244615
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled
# 0              -0.928694                     0.367666
# 1               1.033731                     0.068500
# 2              -0.654867                    -2.324826
# 3               0.805542                    -0.430109
# 4               0.349164                     1.564329

# %%
#We can determine which features the most important using a violin plot to compare the distribution of the feature values for each class.
# source https://seaborn.pydata.org/generated/seaborn.violinplot.html
data = df_clean.copy()
data_std = (data - data.mean()) / data.std()

data = pd.concat([target,data_std.iloc[:,0:9]], axis=1)
data = pd.melt(data, id_vars='blueWins', var_name='Features', value_name='Values')

fig, ax = plt.subplots(1,3,figsize=(15,5))

sns.violinplot(x='Features', y='Values', hue='blueWins', data=data, split=True,
               inner='quart', ax=ax[0], palette='RdBu')
fig.autofmt_xdate(rotation=90)


data = pd.concat([target,data_std.iloc[:,9:19]], axis=1)
data = pd.melt(data, id_vars='blueWins', var_name='Features', value_name='Values')

sns.violinplot(x='Features', y='Values', hue='blueWins', data=data, split=True,
               inner='quart', ax=ax[1], palette='RdBu')
fig.autofmt_xdate(rotation=90)

data = pd.concat([target,data_std.iloc[:,19:29]], axis=1)
data = pd.melt(data, id_vars='blueWins', var_name='Features', value_name='Values')

sns.violinplot(x='Features', y='Values', hue='blueWins', data=data, split=True,
               inner='quart', ax=ax[2], palette='RdBu')
fig.autofmt_xdate(rotation=45)

plt.show()

# %% [markdown]
# Here we can see that BlueAvgLevel and RedAvgLevel does not provide any kind of useful information. There is no correlation with the class blueWins.

# %%
current_df =df_clean.drop(['blueAvgLevel','redAvgLevel'], axis=1).copy()
current_df.head()
# Out:
#    blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  blueDeaths  \
# 0               28                   2               1          9           6
# 1               12                   1               0          5           5
# 2               15                   0               0          7          11
# 3               43                   1               0          4           5
# 4               75                   4               0          6           6
#
#    blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# 0           11                  0            0            0
# 1            5                  0            0            0
# 2            4                  1            1            0
# 3            5                  1            0            1
# 4            6                  0            0            0
#
#    blueTowersDestroyed  blueTotalMinionsKilled  blueTotalJungleMinionsKilled  \
# 0                    0                     195                            36
# 1                    0                     174                            43
# 2                    0                     186                            46
# 3                    0                     201                            55
# 4                    0                     210                            57
#
#    blueGoldDiff  blueExperienceDiff  redWardsPlaced  redWardsDestroyed  \
# 0           643                  -8              15                  6
# 1         -2908               -1173              12                  1
# 2         -1172               -1033              15                  3
# 3         -1321                  -7              15                  2
# 4         -1004                 230              17                  2
#
#    redAssists  redEliteMonsters  redDragons  redHeralds  redTowersDestroyed  \
# 0           8                 0           0           0                   0
# 1           2                 2           1           1                   1
# 2          14                 0           0           0                   0
# 3          10                 0           0           0                   0
# 4           7                 1           1           0                   0
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled
# 0                    197                           55
# 1                    240                           52
# 2                    203                           28
# 3                    235                           47
# 4                    225                           67

# %%
data = current_df.copy()
data_std = (data - data.mean()) / data.std()
# https://seaborn.pydata.org/generated/seaborn.PairGrid.html
data = pd.concat([target,data_std], axis=1)
g = sns.PairGrid(data=data, vars=['blueKills', 'blueGoldDiff'], hue='blueWins', height=4, palette='RdBu')
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()

# %% [markdown]
# By examining the Violent graph, we've determined that there are a lot of co-linearity between the features.

# %% [markdown]
# ### Gold And Experience Analysis
#
# From the swarm plot we see below, we are comparing the gold diff and experience diff from

# %%
# analyze the correlation between the features gold difference and experience difference

sns.set(style='whitegrid', palette='muted')

# we can now rename blueGoldDiff and blueExperienceDiff to goldDiff and experienceDiff
current_df.rename(columns={'blueGoldDiff':'goldDiff', 'blueExperienceDiff':'experienceDiff'}, inplace=True)
current_df.head()

data = current_df[['goldDiff', 'experienceDiff']].sample(1000)
data_std = (data - data.mean()) / data.std()
data = pd.concat([target, data_std], axis=1)
data = pd.melt(data, id_vars='blueWins', var_name='Features', value_name='Values')

# https://seaborn.pydata.org/generated/seaborn.swarmplot.html
plt.figure(figsize=(10,10))
sns.swarmplot(x='Features', y='Values', hue='blueWins', palette='RdBu', data=data)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Elite Monster Analysis
# In this Dataset there are two type of elite monster, the herald and the dragon. Killing these elites will give buffs and or support to the team that defeates them, which will greatly help later on the game. After analysing the weight of the dragonDiff, heraldDiff and eliteDiff, we've came to the following conclusion:
#
# >  - Blue team has a 64% chance of winning if they are ahead in dragon kills before 10 min, 50% chance if equal on dragon kills and 37% if red team is ahead in kills
# >  - Blue team has a 60% chance of winning if they are ahead in herald kills before 10 min, 49% chance if equal on dragon kills and 38% if red team is ahead in kills
#
# The EliteDiff feature is a combination of both dragon and herald, we'll keep the diff feature and remove the rest.

# %%
current_df['dragonsDiff'] = current_df['blueDragons'] - current_df['redDragons']
current_df['heraldsDiff'] = current_df['blueHeralds'] - current_df['redHeralds']
current_df['eliteDiff'] = current_df['blueEliteMonsters'] - current_df['redEliteMonsters']

data = pd.concat([target, current_df], axis=1)

eliteGroups = data.groupby(['eliteDiff'])['blueWins'].mean()
dragonGroups = data.groupby(['dragonsDiff'])['blueWins'].mean()
heraldGroups = data.groupby(['heraldsDiff'])['blueWins'].mean()

fig, ax = plt.subplots(1,2,figsize=(15,5))

dragonGroups.plot(kind='bar', ax=ax[1])
ax[1].set_title('Ratio of Dragons Killed and Wins')
ax[1].set_ylabel('Ratio')

heraldGroups.plot(kind='bar', ax=ax[0])
ax[0].set_title('Ratio of Heralds Killed and Wins')
ax[0].set_ylabel('Ratio')

print(eliteGroups)
print(dragonGroups)
print(heraldGroups)
# Out:
# eliteDiff
# -2    0.286301
# -1    0.368772
#  0    0.500683
#  1    0.632093
#  2    0.735211
# Name: blueWins, dtype: float64
# dragonsDiff
# -1    0.374173
#  0    0.500000
#  1    0.640940
# Name: blueWins, dtype: float64
# heraldsDiff
# -1    0.387729
#  0    0.498680
#  1    0.595046
# Name: blueWins, dtype: float64

# %%
# We added the dragonDiff, heraldsDiff and eliteDiff above and removed the rest here.
columns = ['blueEliteMonsters','blueDragons','blueHeralds','redEliteMonsters','redDragons','redHeralds']
current_df.drop(columns, axis=1, inplace=True)

# %% [markdown]
# ### Towers Destruction Analysis
# In order for blue team to win the game, they must destroy a certain amount of towers to reach the nexus. Having these towers destroy in early game (first 10 min), could be heavily influential for the outcome of the game.
#
# It is however very unlikely that a tower could be destroyed in the first 10 minutes of the game, since it requires a lot dps (damage per second). And this could only happen if the team is stream rolling (thus creating a correlation with gold and kills).

# %%
current_df['towerDiff'] = current_df['blueTowersDestroyed'] - current_df['redTowersDestroyed']
data = pd.concat([target, current_df], axis=1)

towerData = data.groupby(['towerDiff'])['blueWins'].mean()
print(towerData)

ax = plt.plot(figsize=(15,5))
towerData.plot(kind='line')
# Out:
# towerDiff
# -2    0.185185
# -1    0.216138
#  0    0.498124
#  1    0.741379
#  2    0.964286
#  3    1.000000
#  4    1.000000
# Name: blueWins, dtype: float64
# <AxesSubplot: xlabel='towerDiff'>

# %%
columns = ['blueTowersDestroyed','redTowersDestroyed']
current_df.drop(columns, axis=1, inplace=True)

# %% [markdown]
# ### Kill, Assist And Death Analysis

# %%
current_df['killsDiff'] = current_df['blueKills'] - current_df['blueDeaths']
current_df['assistsDiff'] = current_df['blueAssists'] - current_df['redAssists']

sns.set(style='whitegrid', palette='muted')

data = current_df[['blueKills','blueDeaths','blueAssists','redAssists','killsDiff','assistsDiff']].sample(500)
data_std = (data - data.mean()) / data.std()
data = pd.concat([target, data_std], axis=1)
data = pd.melt(data, id_vars='blueWins', var_name='Features', value_name='Values')

plt.figure(figsize=(15,7))
sns.swarmplot(x='Features', y='Values', hue='blueWins', palette='RdBu', data=data)
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 47.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 46.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 35.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 34.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 32.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 19.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 50.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 50.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 39.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 38.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 36.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 23.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 50.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 50.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 39.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 38.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 36.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 23.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# There are two main take aways from these graphs. First of all kills and assists (which often occur with kills) heavily affect the chance of winning, the points are very skewed towards the size with more kills or assists.
#
# Second of all, we notice that the graph with the best correlation is the killsDiff that is proportional to assistDiff. When compare with the blue kills proportional to blue assists graph, we notice that they have the same form but the differential graph is much more dense and compact. Thus, for the prediction model, it is best to use the differential features.

# %%
data = pd.concat([target, current_df], axis=1)

fig, ax = plt.subplots(1,2, figsize=(15,6))
sns.scatterplot(x='killsDiff', y='assistsDiff', hue='blueWins', palette='RdBu', data=data, ax=ax[0])

sns.scatterplot(x='blueKills', y='blueAssists', hue='blueWins', palette='RdBu', data=data, ax=ax[1])
plt.show()

# %% [markdown]
# From the plots above we can clearly see the distinction within killsDiff in the middle where blue wins on the after 0 and blue loses before the 0. Using the kills diff allows us to compare both blue kills and red kills within a single feature which makes our model easier to train.

# %%
# Drop unnecessary features
columns = ['blueFirstBlood','blueKills','blueDeaths','blueAssists','redAssists']
current_df.drop(columns, axis=1, inplace=True)

# %% [markdown]
# ### Minion Kills Analysis

# %%
sns.set(style='whitegrid', palette='muted')

current_df['minionKilledDiff'] = current_df['blueTotalMinionsKilled'] - current_df['redTotalMinionsKilled']
current_df['jungleMinionKilledDiff'] = current_df['blueTotalJungleMinionsKilled'] - current_df['redTotalJungleMinionsKilled']

# Drop unnecessary features
column = ['blueTotalMinionsKilled','redTotalMinionsKilled','blueTotalJungleMinionsKilled','redTotalJungleMinionsKilled']

current_df.drop(column, axis=1, inplace=True)
data = current_df[['minionKilledDiff', 'jungleMinionKilledDiff']].sample(1000)
data_std = (data - data.mean()) / data.std()
data = pd.concat([target, data_std], axis=1)
data = pd.melt(data, id_vars='blueWins', var_name='Features',value_name='Values')

plt.figure(figsize=(15,5))
sns.swarmplot(x='Features', y='Values', hue='blueWins', palette='RdBu', data=data)
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 14.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 14.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# We notice that there is a small corellation between minion Kills and blueWins, thus we can use the minionKilledDiff feature and remove the red and blue total minion killed features.
#
# We notice that there is no corellation between jungle minion kills and blue wins, the dots are randomly place and show no pattern. Thus we can remove any feature related to jungle minions

# %%
column = ['jungleMinionKilledDiff']

current_df.drop(column, axis=1, inplace=True)

# %% [markdown]
# #### Correlation
# Now lets create the correlation-matrix and find all feature that has a correlation higher then 0.2 or lower then -0.2. We exclude everything else  since they are redundant and has no effect on the prediction.

# %%
plt.figure(figsize=(16, 12))
data = pd.concat([target, current_df], axis=1)
#https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.heatmap(data.corr(), cmap='YlGnBu', annot=True )
# Out:
# <AxesSubplot: >

# %%
# find all column that have correlation greater than 0.2 or less than -0.2
data = pd.concat([target, current_df], axis=1)
corr_list = round(data.corr().blueWins,2)
corr_list = corr_list[(corr_list > 0.2) | (corr_list < -0.2)]
cols = []
# append the column name to cols
for i in corr_list.index:
    cols.append(i)
cols.remove('blueWins')
corr_list
# Out:
# blueWins            1.00
# goldDiff            0.51
# experienceDiff      0.49
# dragonsDiff         0.23
# eliteDiff           0.26
# killsDiff           0.48
# assistsDiff         0.39
# minionKilledDiff    0.31
# Name: blueWins, dtype: float64

# %%
# drop columns that have correlation less than 0.2 or greater than -0.2
features_data = current_df[cols]
features_data.head()
# Out:
#    goldDiff  experienceDiff  dragonsDiff  eliteDiff  killsDiff  assistsDiff  \
# 0       643              -8            0          0          3            3
# 1     -2908           -1173           -1         -2          0            3
# 2     -1172           -1033            1          1         -4          -10
# 3     -1321              -7            0          1         -1           -5
# 4     -1004             230           -1         -1          0           -1
#
#    minionKilledDiff
# 0                -2
# 1               -66
# 2               -17
# 3               -34
# 4               -15

# %% [markdown]
# This will be our final list of feature that we will use to machine learn

# %% [markdown]
# ## Lets Machine Learn

# %%
# Import libraries for machine learning models
from sklearn import preprocessing, metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

print('Machine Learning Libraries Imported!')
# Out:
# Machine Learning Libraries Imported!

# %%
print(features_data.shape,target.shape)
# Out:
# (9879, 7) (9879,)

# %% [markdown]
# ### 5) Preparing the data

# %%
#setting up 10-fold to use for cross validation
#https://www.askpython.com/python/examples/k-fold-cross-validation
k = 10
cv = KFold(n_splits=k, random_state= None)

features = preprocessing.StandardScaler().fit(features_data).transform(features_data.astype(float))

# %%
# get confusion matrix 
def get_confusion_matrix(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    return cm

def get_accuracy(y_test, y_pred):
    return metrics.accuracy_score(y_test, y_pred)

def get_recall(y_test, y_pred):
    return metrics.recall_score(y_test, y_pred)

def get_precision(y_test, y_pred):
    return metrics.precision_score(y_test, y_pred)

def get_f_score(y_test, y_pred):
    return metrics.f1_score(y_test, y_pred)

def get_metrics(algorithm, y_test, y_pred):
    accuracy = get_accuracy(y_test, y_pred)
    recall = get_recall(y_test, y_pred)
    precision = get_precision(y_test, y_pred)
    f_score = get_f_score(y_test, y_pred)
    return algorithm, accuracy, recall, precision, f_score

# %% [markdown]
# ## 6,7 and 8) Training the three different models

# %% [markdown]
# #### Attempt #1

# %%
GNB_1 = GaussianNB()
LR_1 = LogisticRegression()
MLP_1 = MLPClassifier()
#setting up new table
modelsGNB = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])
#setting up new table
modelsLR = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])
#setting up new table
modelsMLP = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])

#inspired from https://www.askpython.com/python/examples/k-fold-cross-validation
for train_index , test_index in cv.split(features):
    X_train , X_test = features[train_index,:],features[test_index,:]
    y_train , y_test = target[train_index] , target[test_index]
    

    GNB_1.fit(X_train,y_train)
    pred_values_GNB = GNB_1.predict(X_test)


    LR_1.fit(X_train,y_train)
    pred_values_LR = LR_1.predict(X_test)

    MLP_1.fit(X_train,y_train)
    pred_values_MLP = MLP_1.predict(X_test)

    
    algorithm, accuracy, recall, precision, f_score = get_metrics('Bayes', y_test, pred_values_GNB)
    modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

    algorithm, accuracy, recall, precision, f_score = get_metrics('LogReg', y_test, pred_values_LR)
    modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

    
    algorithm, accuracy, recall, precision, f_score = get_metrics('MLP', y_test, pred_values_MLP)
    modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# Out:
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /opt/homebrew/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /opt/homebrew/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /opt/homebrew/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /opt/homebrew/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB = modelsGNB.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR = modelsLR.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/1242090768.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP = modelsMLP.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

# %%
modelsGNB
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0     Bayes  0.748988  0.759259   0.738000  0.748479
# 1     Bayes  0.717611  0.697154   0.725159  0.710881
# 2     Bayes  0.726721  0.726695   0.708678  0.717573
# 3     Bayes  0.717611  0.708087   0.732653  0.720160
# 4     Bayes  0.738866  0.740125   0.728016  0.734021
# 5     Bayes  0.722672  0.727447   0.741683  0.734496
# 6     Bayes  0.722672  0.722772   0.731463  0.727092
# 7     Bayes  0.741903  0.746809   0.720739  0.733542
# 8     Bayes  0.735830  0.729524   0.762948  0.745862
# 9     Bayes  0.707194  0.717622   0.684211  0.700518

# %%
modelsLR
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0    LogReg  0.746964  0.761317   0.734127  0.747475
# 1    LogReg  0.725709  0.707317   0.732632  0.719752
# 2    LogReg  0.734818  0.733051   0.717842  0.725367
# 3    LogReg  0.726721  0.712032   0.744330  0.727823
# 4    LogReg  0.731781  0.735967   0.719512  0.727646
# 5    LogReg  0.723684  0.727447   0.743137  0.735209
# 6    LogReg  0.728745  0.732673   0.735586  0.734127
# 7    LogReg  0.755061  0.746809   0.740506  0.743644
# 8    LogReg  0.743927  0.748571   0.764591  0.756497
# 9    LogReg  0.710233  0.730361   0.683897  0.706366

# %%
modelsMLP
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0       MLP  0.733806  0.734568   0.727088  0.730809
# 1       MLP  0.722672  0.705285   0.728992  0.716942
# 2       MLP  0.739879  0.739407   0.722567  0.730890
# 3       MLP  0.723684  0.700197   0.745798  0.722279
# 4       MLP  0.732794  0.725572   0.725572  0.725572
# 5       MLP  0.722672  0.723608   0.743590  0.733463
# 6       MLP  0.725709  0.720792   0.736842  0.728729
# 7       MLP  0.744939  0.731915   0.731915  0.731915
# 8       MLP  0.743927  0.758095   0.759542  0.758818
# 9       MLP  0.706180  0.723992   0.680639  0.701646

# %% [markdown]
# ## 9) Modifying Model Paramteres

# %% [markdown]
# #### Attempt #2

# %%
GNB_2 = GaussianNB (var_smoothing=0.000000001)
#https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
LR_2 = LogisticRegression(penalty='elasticnet', C=0.05, solver='saga', max_iter=500, l1_ratio=0.5)
#https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#
MLP_2 = MLPClassifier(hidden_layer_sizes=(100, ), alpha=0.0001,  max_iter=500, early_stopping=True)
#setting up new table
modelsGNB_2 = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])
#setting up new table
modelsLR_2 = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])
#setting up new table
modelsMLP_2 = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])

#inspired from https://www.askpython.com/python/examples/k-fold-cross-validation
for train_index , test_index in cv.split(features):
    X_train , X_test = features[train_index,:],features[test_index,:]
    y_train , y_test = target[train_index] , target[test_index]
    

    GNB_2.fit(X_train,y_train)
    pred_values_GNB = GNB_2.predict(X_test)


    LR_2.fit(X_train,y_train)
    pred_values_LR = LR_2.predict(X_test)

    MLP_2.fit(X_train,y_train)
    pred_values_MLP = MLP_2.predict(X_test)

    
    algorithm, accuracy, recall, precision, f_score = get_metrics('Bayes', y_test, pred_values_GNB)
    modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

    algorithm, accuracy, recall, precision, f_score = get_metrics('LogReg', y_test, pred_values_LR)
    modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

    
    algorithm, accuracy, recall, precision, f_score = get_metrics('MLP', y_test, pred_values_MLP)
    modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# Out:
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_2 = modelsGNB_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_2 = modelsLR_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/86891372.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_2 = modelsMLP_2.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

# %%
modelsGNB_2
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0     Bayes  0.748988  0.759259   0.738000  0.748479
# 1     Bayes  0.717611  0.697154   0.725159  0.710881
# 2     Bayes  0.726721  0.726695   0.708678  0.717573
# 3     Bayes  0.717611  0.708087   0.732653  0.720160
# 4     Bayes  0.738866  0.740125   0.728016  0.734021
# 5     Bayes  0.722672  0.727447   0.741683  0.734496
# 6     Bayes  0.722672  0.722772   0.731463  0.727092
# 7     Bayes  0.741903  0.746809   0.720739  0.733542
# 8     Bayes  0.735830  0.729524   0.762948  0.745862
# 9     Bayes  0.707194  0.717622   0.684211  0.700518

# %%
modelsLR_2
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0    LogReg  0.750000  0.767490   0.735700  0.751259
# 1    LogReg  0.729757  0.709350   0.737844  0.723316
# 2    LogReg  0.732794  0.735169   0.713992  0.724426
# 3    LogReg  0.723684  0.704142   0.743750  0.723404
# 4    LogReg  0.733806  0.735967   0.722449  0.729145
# 5    LogReg  0.724696  0.725528   0.745562  0.735409
# 6    LogReg  0.728745  0.730693   0.736527  0.733598
# 7    LogReg  0.750000  0.746809   0.732777  0.739726
# 8    LogReg  0.741903  0.744762   0.763672  0.754098
# 9    LogReg  0.713273  0.732484   0.687251  0.709147

# %%
modelsMLP_2
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0       MLP  0.744939  0.759259   0.732143  0.745455
# 1       MLP  0.719636  0.695122   0.729211  0.711759
# 2       MLP  0.728745  0.743644   0.704819  0.723711
# 3       MLP  0.718623  0.694280   0.741053  0.716904
# 4       MLP  0.728745  0.731809   0.716904  0.724280
# 5       MLP  0.721660  0.708253   0.750000  0.728529
# 6       MLP  0.719636  0.702970   0.736515  0.719352
# 7       MLP  0.738866  0.736170   0.720833  0.728421
# 8       MLP  0.736842  0.731429   0.763419  0.747082
# 9       MLP  0.716312  0.736730   0.689861  0.712526

# %% [markdown]
# ### Attempt #3

# %%
GNB_3 = GaussianNB(var_smoothing=0.000001)
#https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
LR_3 = LogisticRegression(penalty='l1', C=0.01, solver='liblinear', max_iter=500)
#https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#
MLP_3 = MLPClassifier(hidden_layer_sizes=(100, ), alpha=0.0005, batch_size=500, learning_rate='invscaling', learning_rate_init=0.005, power_t=0.5, max_iter=500)
#setting up new table
modelsGNB_3 = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])
#setting up new table
modelsLR_3 = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])
#setting up new table
modelsMLP_3 = pd.DataFrame(columns=['Algorithm', 'Accuracy', 'Recall', 'Precision', 'F_score'])

data_mlp = []
data_lr = []
data_gnb = []

#inspired from https://www.askpython.com/python/examples/k-fold-cross-validation
for train_index , test_index in cv.split(features):
    X_train , X_test = features[train_index,:],features[test_index,:]
    y_train , y_test = target[train_index] , target[test_index]

    GNB_3.fit(X_train,y_train)
    pred_values_GNB = GNB_3.predict(X_test)
    #append to list
    data_gnb.append([y_test, pred_values_GNB])

    LR_3.fit(X_train,y_train)
    pred_values_LR = LR_3.predict(X_test)

    MLP_3.fit(X_train,y_train)
    pred_values_MLP = MLP_3.predict(X_test)

    
    algorithm, accuracy, recall, precision, f_score = get_metrics('Bayes', y_test, pred_values_GNB)
    modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

    algorithm, accuracy, recall, precision, f_score = get_metrics('LogReg', y_test, pred_values_LR)
    modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

    
    algorithm, accuracy, recall, precision, f_score = get_metrics('MLP', y_test, pred_values_MLP)
    modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# Out:
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsGNB_3 = modelsGNB_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsLR_3 = modelsLR_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)
# /var/folders/3t/5pjg6h_14dz4ybl_8js69w4c0000gn/T/ipykernel_928/3949285041.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modelsMLP_3 = modelsMLP_3.append({'Algorithm': algorithm, 'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F_score': f_score}, ignore_index=True)

# %%
modelsGNB_3
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0     Bayes  0.748988  0.759259   0.738000  0.748479
# 1     Bayes  0.717611  0.697154   0.725159  0.710881
# 2     Bayes  0.726721  0.726695   0.708678  0.717573
# 3     Bayes  0.717611  0.708087   0.732653  0.720160
# 4     Bayes  0.738866  0.740125   0.728016  0.734021
# 5     Bayes  0.722672  0.727447   0.741683  0.734496
# 6     Bayes  0.722672  0.722772   0.731463  0.727092
# 7     Bayes  0.741903  0.746809   0.720739  0.733542
# 8     Bayes  0.735830  0.729524   0.762948  0.745862
# 9     Bayes  0.707194  0.717622   0.684211  0.700518

# %%
modelsLR_3
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0    LogReg  0.750000  0.769547   0.734774  0.751759
# 1    LogReg  0.732794  0.721545   0.736515  0.728953
# 2    LogReg  0.738866  0.737288   0.721992  0.729560
# 3    LogReg  0.726721  0.715976   0.742331  0.728916
# 4    LogReg  0.731781  0.738046   0.718623  0.728205
# 5    LogReg  0.721660  0.729367   0.739300  0.734300
# 6    LogReg  0.726721  0.734653   0.731755  0.733202
# 7    LogReg  0.756073  0.751064   0.740042  0.745512
# 8    LogReg  0.746964  0.756190   0.764933  0.760536
# 9    LogReg  0.715299  0.732484   0.690000  0.710608

# %%
modelsMLP_3
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0       MLP  0.734818  0.728395   0.731405  0.729897
# 1       MLP  0.730769  0.743902   0.723320  0.733467
# 2       MLP  0.722672  0.728814   0.702041  0.715177
# 3       MLP  0.710526  0.680473   0.735608  0.706967
# 4       MLP  0.732794  0.735967   0.720978  0.728395
# 5       MLP  0.720648  0.729367   0.737864  0.733591
# 6       MLP  0.722672  0.742574   0.722543  0.732422
# 7       MLP  0.744939  0.744681   0.726141  0.735294
# 8       MLP  0.728745  0.758095   0.738404  0.748120
# 9       MLP  0.705167  0.717622   0.681452  0.699069

# %% [markdown]
# ## 10)
#
# a)
#   - Comparing Naive Bayes Attempts

# %%
modelsGNB
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0     Bayes  0.748988  0.759259   0.738000  0.748479
# 1     Bayes  0.717611  0.697154   0.725159  0.710881
# 2     Bayes  0.726721  0.726695   0.708678  0.717573
# 3     Bayes  0.717611  0.708087   0.732653  0.720160
# 4     Bayes  0.738866  0.740125   0.728016  0.734021
# 5     Bayes  0.722672  0.727447   0.741683  0.734496
# 6     Bayes  0.722672  0.722772   0.731463  0.727092
# 7     Bayes  0.741903  0.746809   0.720739  0.733542
# 8     Bayes  0.735830  0.729524   0.762948  0.745862
# 9     Bayes  0.707194  0.717622   0.684211  0.700518

# %%
modelsGNB_2
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0     Bayes  0.748988  0.759259   0.738000  0.748479
# 1     Bayes  0.717611  0.697154   0.725159  0.710881
# 2     Bayes  0.726721  0.726695   0.708678  0.717573
# 3     Bayes  0.717611  0.708087   0.732653  0.720160
# 4     Bayes  0.738866  0.740125   0.728016  0.734021
# 5     Bayes  0.722672  0.727447   0.741683  0.734496
# 6     Bayes  0.722672  0.722772   0.731463  0.727092
# 7     Bayes  0.741903  0.746809   0.720739  0.733542
# 8     Bayes  0.735830  0.729524   0.762948  0.745862
# 9     Bayes  0.707194  0.717622   0.684211  0.700518

# %%
modelsGNB_3
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0     Bayes  0.748988  0.759259   0.738000  0.748479
# 1     Bayes  0.717611  0.697154   0.725159  0.710881
# 2     Bayes  0.726721  0.726695   0.708678  0.717573
# 3     Bayes  0.717611  0.708087   0.732653  0.720160
# 4     Bayes  0.738866  0.740125   0.728016  0.734021
# 5     Bayes  0.722672  0.727447   0.741683  0.734496
# 6     Bayes  0.722672  0.722772   0.731463  0.727092
# 7     Bayes  0.741903  0.746809   0.720739  0.733542
# 8     Bayes  0.735830  0.729524   0.762948  0.745862
# 9     Bayes  0.707194  0.717622   0.684211  0.700518

# %% [markdown]
#   - Comparing Logistical Regression Attempts
# For the second attempt, we modified

# %%
modelsLR
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0    LogReg  0.746964  0.761317   0.734127  0.747475
# 1    LogReg  0.725709  0.707317   0.732632  0.719752
# 2    LogReg  0.734818  0.733051   0.717842  0.725367
# 3    LogReg  0.726721  0.712032   0.744330  0.727823
# 4    LogReg  0.731781  0.735967   0.719512  0.727646
# 5    LogReg  0.723684  0.727447   0.743137  0.735209
# 6    LogReg  0.728745  0.732673   0.735586  0.734127
# 7    LogReg  0.755061  0.746809   0.740506  0.743644
# 8    LogReg  0.743927  0.748571   0.764591  0.756497
# 9    LogReg  0.710233  0.730361   0.683897  0.706366

# %%
modelsLR_2
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0    LogReg  0.750000  0.767490   0.735700  0.751259
# 1    LogReg  0.729757  0.709350   0.737844  0.723316
# 2    LogReg  0.732794  0.735169   0.713992  0.724426
# 3    LogReg  0.723684  0.704142   0.743750  0.723404
# 4    LogReg  0.733806  0.735967   0.722449  0.729145
# 5    LogReg  0.724696  0.725528   0.745562  0.735409
# 6    LogReg  0.728745  0.730693   0.736527  0.733598
# 7    LogReg  0.750000  0.746809   0.732777  0.739726
# 8    LogReg  0.741903  0.744762   0.763672  0.754098
# 9    LogReg  0.713273  0.732484   0.687251  0.709147

# %%
modelsLR_3
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0    LogReg  0.750000  0.769547   0.734774  0.751759
# 1    LogReg  0.732794  0.721545   0.736515  0.728953
# 2    LogReg  0.738866  0.737288   0.721992  0.729560
# 3    LogReg  0.726721  0.715976   0.742331  0.728916
# 4    LogReg  0.731781  0.738046   0.718623  0.728205
# 5    LogReg  0.721660  0.729367   0.739300  0.734300
# 6    LogReg  0.726721  0.734653   0.731755  0.733202
# 7    LogReg  0.756073  0.751064   0.740042  0.745512
# 8    LogReg  0.746964  0.756190   0.764933  0.760536
# 9    LogReg  0.715299  0.732484   0.690000  0.710608

# %% [markdown]
#   - Comparing MLP attempts

# %%
modelsMLP
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0       MLP  0.733806  0.734568   0.727088  0.730809
# 1       MLP  0.722672  0.705285   0.728992  0.716942
# 2       MLP  0.739879  0.739407   0.722567  0.730890
# 3       MLP  0.723684  0.700197   0.745798  0.722279
# 4       MLP  0.732794  0.725572   0.725572  0.725572
# 5       MLP  0.722672  0.723608   0.743590  0.733463
# 6       MLP  0.725709  0.720792   0.736842  0.728729
# 7       MLP  0.744939  0.731915   0.731915  0.731915
# 8       MLP  0.743927  0.758095   0.759542  0.758818
# 9       MLP  0.706180  0.723992   0.680639  0.701646

# %%
modelsMLP_2
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0       MLP  0.744939  0.759259   0.732143  0.745455
# 1       MLP  0.719636  0.695122   0.729211  0.711759
# 2       MLP  0.728745  0.743644   0.704819  0.723711
# 3       MLP  0.718623  0.694280   0.741053  0.716904
# 4       MLP  0.728745  0.731809   0.716904  0.724280
# 5       MLP  0.721660  0.708253   0.750000  0.728529
# 6       MLP  0.719636  0.702970   0.736515  0.719352
# 7       MLP  0.738866  0.736170   0.720833  0.728421
# 8       MLP  0.736842  0.731429   0.763419  0.747082
# 9       MLP  0.716312  0.736730   0.689861  0.712526

# %%
modelsMLP_3
# Out:
#   Algorithm  Accuracy    Recall  Precision   F_score
# 0       MLP  0.734818  0.728395   0.731405  0.729897
# 1       MLP  0.730769  0.743902   0.723320  0.733467
# 2       MLP  0.722672  0.728814   0.702041  0.715177
# 3       MLP  0.710526  0.680473   0.735608  0.706967
# 4       MLP  0.732794  0.735967   0.720978  0.728395
# 5       MLP  0.720648  0.729367   0.737864  0.733591
# 6       MLP  0.722672  0.742574   0.722543  0.732422
# 7       MLP  0.744939  0.744681   0.726141  0.735294
# 8       MLP  0.728745  0.758095   0.738404  0.748120
# 9       MLP  0.705167  0.717622   0.681452  0.699069

# %% [markdown]
# #### b) False positive and False Negative Example

# %%
#the testing data for GNB attempt 3   - data_gnb[9][0]
#the predicted data for GNB attempt 3   - data_gnb[9][1]

# find the index of features that is false positive using the confusion matrix
fp = np.where((data_gnb[9][0] == 0) & (data_gnb[9][1] == 1))[0]

# find the index of features that is false negative using the confusion matrix
fn = np.where((data_gnb[9][0] == 1) & (data_gnb[9][1] == 0))[0]


print('False Positive: ',  fp.size)
print('False Negative: ',  fn.size)
# Out:
# False Positive:  156
# False Negative:  133

# %% [markdown]
# ##### False positive and False Negative Example

# %%
fpExample = features_data.iloc[fp[0]]
print("false_positive_example:\n", fpExample,"\n")

fnExample = features_data.iloc[fn[0]]
print("false_negative_example:\n", fnExample,"\n")
# Out:
# false_positive_example:
#  goldDiff           -2908
# experienceDiff     -1173
# dragonsDiff           -1
# eliteDiff             -2
# killsDiff              0
# assistsDiff            3
# minionKilledDiff     -66
# Name: 1, dtype: int64
#
# false_negative_example:
#  goldDiff            5228
# experienceDiff      3378
# dragonsDiff           -1
# eliteDiff             -1
# killsDiff              8
# assistsDiff            6
# minionKilledDiff      53
# Name: 16, dtype: int64

# %% [markdown]
# ##### Analysing The confusion matrix of these examples

# %% [markdown]
# For naive Bayes, it seems like we are getting a false positive when the gold and experience differential is in the negative ( which should mean that blue loses), the reason for this might be because kill diff, and assist diff is somewhat positive. Since each attribute hold the same weight, we can not prioritize gold and experience.
#
# Same thing for false negative, we are predicting that blue loses when the goldDiff and experienceDiff is in the positive ( which should result in blue winning), most of the attributes are close to 0, which will make it really hard to predict correctly.

# %% [markdown]
# ##### True positive and True Negative Example

# %%
# find the index of features that is true positive using the confusion matrix
tp = np.where((data_gnb[9][0] == 1) & (data_gnb[9][1] == 1))[0]

# find the index of features that is true negative using the confusion matrix
tn = np.where((data_gnb[9][0] == 0) & (data_gnb[9][1] == 0))[0]

print('True Positive: ',  tp.size)
print('True Negative: ',  tn.size)
# Out:
# True Positive:  338
# True Negative:  360

# %%
tpExample = features_data.iloc[tp[0]]
print("true_positive_example:\n",tpExample,"\n")

tnExample = features_data.iloc[tn[0]]
print("true_negative_example:\n",tnExample,"\n")
# Out:
# true_positive_example:
#  goldDiff            643
# experienceDiff       -8
# dragonsDiff           0
# eliteDiff             0
# killsDiff             3
# assistsDiff           3
# minionKilledDiff     -2
# Name: 0, dtype: int64
#
# true_negative_example:
#  goldDiff           -1172
# experienceDiff     -1033
# dragonsDiff            1
# eliteDiff              1
# killsDiff             -4
# assistsDiff          -10
# minionKilledDiff     -17
# Name: 2, dtype: int64

# %% [markdown]
# ##### Analysing The confusion matrix of these examples

# %% [markdown]
# For the true positive example, we can see that the gold differential attribute is in the positive, and most attribute are in the positive, this would result in blue winning. This makes sense with the game, since when a team gets ahead the enememy team received more gold (bounty system) when they kill the blue team. Allowing for a comeback mechanic to happen. Even in the highest level of play sometimes the champions chosen or the way the game is played will affect the game alot more than gold/exp.
#
# For the true negative example, most attributes are in the negative, which will result in blue losing. For the same reason as true positive, games are not decided at 10 minutes so it's really hard to predict this.
